# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewReid854/reliability/blob/master/docs/collab/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install reliability

# %%
from reliability.Distributions import Weibull_Distribution
dist = Weibull_Distribution(alpha=5,beta=2)
dist.plot()
